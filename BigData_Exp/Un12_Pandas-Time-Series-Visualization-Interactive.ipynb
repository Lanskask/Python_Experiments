# %% [markdown]
# # Un12_Pandas-Time-Series-Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
mcdon = pd.read_csv('DataIO/PandasVisualization/mcdonalds.csv', index_col='Date',parse_dates=True)

# %%
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
mcdon['Adj. Close'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
