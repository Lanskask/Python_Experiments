# %% [markdown]
# DAta about airoports
# http://ourairports.com/data/

# %%
import pandas as pd

airports = pd.read_csv('data/airports.csv')
airport_freq = pd.read_csv('data/airport-frequencies.csv')
runways = pd.read_csv('data/runways.csv')

# %%
airports.sort_values('ident')
# Out:
#            id ident           type  \
# 0        6523   00A       heliport
# 1      323361  00AA  small_airport
# 2        6524  00AK  small_airport
# 3        6525  00AL  small_airport
# 4        6526  00AR         closed
# 5      322127  00AS  small_airport
# 6        6527  00AZ  small_airport
# 7        6528  00CA  small_airport
# 8      324424  00CL  small_airport
# 9      322658  00CN       heliport
# 10       6529  00CO         closed
# 11       6531  00FA  small_airport
# 12       6532  00FD       heliport
# 13       6533  00FL  small_airport
# 14       6534  00GA  small_airport
# 15       6535  00GE       heliport
# 16       6536  00HI       heliport
# 17       6537  00ID  small_airport
# 18     322581  00IG  small_airport
# 19       6538  00II       heliport
# 20       6539  00IL  small_airport
# 21       6540  00IN       heliport
# 22       6541  00IS  small_airport
# 23       6542  00KS  small_airport
# 24       6543  00KY  small_airport
# 25      45437  00LA       heliport
# 26       6544  00LL       heliport
# 27       6545  00LS  small_airport
# 28       6546  00MD  small_airport
# 29       6547  00MI       heliport
# ...       ...   ...            ...
# 14571  299263  cjj3  small_airport
# 14941  299244  cla5  small_airport
# 14958  301320  clj3  small_airport
# 14967  299264  cln4  small_airport
# 14972  302187  cls3  small_airport
# 14973  299265  clv2  small_airport
# 14987  299180  cmb2  small_airport
# 15290  301322  cnl7  small_airport
# 15525  301225  cor2       heliport
# 15722  301323  crs7  small_airport
# 15723  300230  crt2  small_airport
# 15804  299268  csm7       heliport
# 15850  299269  csv8  small_airport
# 16120   44471  cvb2  small_airport
# 16142  299277  cwf2  small_airport
# 16148  302189  cwp3       heliport
# 31432   46653  lhkk  small_airport
# 32086  309711  lrpv  small_airport
# 32761  301617  mder  small_airport
# 32762  301618  mdes  small_airport
# 32764  301621  mdhn  small_airport
# 32766  301622  mdji  small_airport
# 32767  301615  mdll  small_airport
# 32768  301623  mdlm  small_airport
# 32770  301616  mdma  small_airport
# 32773  301619  mdpm  small_airport
# 32784  301620  mdwo  small_airport
# 39223  299106   qfx       heliport
# 39364  299238  rjns  large_airport
# 45469  313312  spgl  small_airport
#
#                                                  name  latitude_deg  \
# 0                                   Total Rf Heliport     40.070801
# 1                                Aero B Ranch Airport     38.704022
# 2                                        Lowell Field     59.949200
# 3                                        Epps Airpark     34.864799
# 4                  Newport Hospital & Clinic Heliport     35.608700
# 5                                      Fulton Airport     34.942803
# 6                                      Cordes Airport     34.305599
# 7                             Goldstone /Gts/ Airport     35.350498
# 8                                 Williams Ag Airport     39.427188
# 9                     Kitchen Creek Helibase Heliport     32.727374
# 10                                         Cass Field     40.622202
# 11                                Grass Patch Airport     28.645500
# 12                                 Ringhaver Heliport     28.846600
# 13                                  River Oak Airport     27.230900
# 14                                   Lt World Airport     33.767502
# 15                                   Caffrey Heliport     33.884201
# 16                                 Kaupulehu Heliport     19.832715
# 17                               Delta Shores Airport     48.145302
# 18                                      Goltl Airport     39.724028
# 19                 Bailey Generation Station Heliport     41.644501
# 20                                     Hammer Airport     41.978401
# 21                    St Mary Medical Center Heliport     41.511398
# 22                  Hayenga's Cant Find Farms Airport     40.025600
# 23                                Hayden Farm Airport     38.727798
# 24                              Robbins Roost Airport     37.409401
# 25                  Shell Chemical East Site Heliport     30.191944
# 26                         Ac & R Components Heliport     39.665298
# 27                                    Lejeune Airport     30.136299
# 28                                       Slater Field     38.757099
# 29                              Dow Chemical Heliport     43.949402
# ...                                               ...           ...
# 14571            Wildwood / Loche Mist Farms Airstrip     53.546531
# 14941                     Lethbridge / Anderson Field     49.656944
# 14958                        Lethbridge / J3 Airfield     49.741621
# 14967                   Beaverlodge / Clanachan Field     55.234493
# 14972            Fort McMurray / South Liege Airfield     56.832353
# 14973               Stayner (Clearview Field) Airport     44.404638
# 14987                              Meadowbank Airport     65.024662
# 15290                        Nobel / Lumsden Air Park     45.408333
# 15525                  Val D'or (St. Pierre) Heliport     48.077434
# 15722                                 Matoush Airport     51.905000
# 15723  Rivière Témiscamie (Air Roberval Ltée) Airport     51.009247
# 15804                     Abbotsford (Sumas Mountain)     49.105322
# 15850     Schomberg (Sloan Valley View Farm Airfield)     43.986145
# 16120                                    Voisey's Bay     56.344722
# 16142             Walter's Falls (Piper Way) Airfield     44.463880
# 16148   Leslieville / W. Pidhirney Residence Heliport     52.359274
# 31432                           Kiskunlacháza-airport     47.168885
# 32086                             Aerodromul Strejnic     44.923670
# 32761                             El Ranchito Airport     19.184813
# 32762                       Peñuela / Esperanza Field     19.584112
# 32764                      Juancho Enriquillo Airport     17.872519
# 32766                                  Jimani Airport     18.492850
# 32767                Los Llanos de Sabanatosa Airport     18.596426
# 32768                            Los Montones Airport     18.521233
# 32770                          Magdalena Cuya Airport     18.501933
# 32773                                  Piloto Airport     19.597727
# 32784                                Walterio Airport     19.757867
# 39223                                Igaliku Heliport     60.992007
# 39364                       Mt. Fuji Shizuoka Airport     34.796043
# 45469                                 Chagual Airport     -7.798106
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 1        -101.473911        3435.0       NaN          US      US-KS
# 2        -151.695999         450.0       NaN          US      US-AK
# 3         -86.770302         820.0       NaN          US      US-AL
# 4         -91.254898         237.0       NaN          US      US-AR
# 5         -97.818019        1100.0       NaN          US      US-OK
# 6        -112.165001        3810.0       NaN          US      US-AZ
# 7        -116.888000        3038.0       NaN          US      US-CA
# 8        -121.763427          87.0       NaN          US      US-CA
# 9        -116.459742        3350.0       NaN          US      US-CA
# 10       -104.344002        4830.0       NaN          US      US-CO
# 11        -82.219002          53.0       NaN          US      US-FL
# 12        -82.345398          25.0       NaN          US      US-FL
# 13        -80.969200          35.0       NaN          US      US-FL
# 14        -84.068298         700.0       NaN          US      US-GA
# 15        -84.733902         957.0       NaN          US      US-GA
# 16       -155.980233          43.0       NaN          US      US-HI
# 17       -116.213997        2064.0       NaN          US      US-ID
# 18       -101.395994        3359.0       NaN          US      US-KS
# 19        -87.122803         600.0       NaN          US      US-IN
# 20        -89.560402         840.0       NaN          US      US-IL
# 21        -87.260597         634.0       NaN          US      US-IN
# 22        -89.122902         820.0       NaN          US      US-IL
# 23        -94.930496        1100.0       NaN          US      US-KS
# 24        -84.619698        1265.0       NaN          US      US-KY
# 25        -90.980833          15.0       NaN          US      US-LA
# 26        -89.705597         600.0       NaN          US      US-IL
# 27        -92.429398          12.0       NaN          US      US-LA
# 28        -75.753799          45.0       NaN          US      US-MD
# 29        -86.416702         588.0       NaN          US      US-MI
# ...              ...           ...       ...         ...        ...
# 14571    -115.260657        2880.0       NaN          CA      CA-AB
# 14941    -112.772778        3020.0       NaN          CA      CA-AB
# 14958    -112.738330        2910.0       NaN          CA      CA-AB
# 14967    -119.841591        2694.0       NaN          CA      CA-AB
# 14972    -113.098841        1707.0       NaN          CA      CA-AB
# 14973     -80.147978         870.0       NaN          CA      CA-ON
# 14987     -96.068659         475.0       NaN          CA      CA-NU
# 15290     -80.078056         720.0       NaN          CA      CA-ON
# 15525     -77.868626        1000.0       NaN          CA      CA-QC
# 15722     -72.123889        2608.0       NaN          CA      CA-QC
# 15723     -72.983594        1300.0       NaN          CA      CA-QC
# 15804    -122.197441        1067.0       NaN          CA      CA-BC
# 15850     -79.727290         890.0       NaN          CA      CA-ON
# 16120     -62.088056           NaN       NaN          CA      CA-NL
# 16142     -80.621474        1400.0       NaN          CA      CA-ON
# 16148    -114.571347        3130.0       NaN          CA      CA-AB
# 31432      19.084969         322.0        EU          HU      HU-PE
# 32086      25.963418         240.0        EU          RO      RO-PH
# 32761     -70.364964         240.0       NaN          DO      DO-13
# 32762     -70.956724         328.0       NaN          DO      DO-27
# 32764     -71.268718         115.0       NaN          DO      DO-04
# 32766     -71.869999           NaN       NaN          DO      DO-10
# 32767     -69.525776         262.0       NaN          DO      DO-23
# 32768     -70.099132         305.0       NaN          DO      DO-21
# 32770     -68.799099         325.0       NaN          DO      DO-12
# 32773     -71.205971         131.0       NaN          DO      DO-15
# 32784     -71.623482          33.0       NaN          DO      DO-15
# 39223     -45.432335           NaN       NaN          GL     GL-U-A
# 39364     138.187752         433.0        AS          JP      JP-22
# 45469     -77.649500        3967.0        SA          PE     PE-LAL
#
#                             municipality scheduled_service gps_code iata_code  \
# 0                               Bensalem                no      00A       NaN
# 1                                  Leoti                no     00AA       NaN
# 2                           Anchor Point                no     00AK       NaN
# 3                                Harvest                no     00AL       NaN
# 4                                Newport                no      NaN       NaN
# 5                                   Alex                no     00AS       NaN
# 6                                 Cordes                no     00AZ       NaN
# 7                                Barstow                no     00CA       NaN
# 8                                  Biggs                no     00CL       NaN
# 9                            Pine Valley                no     00CN       NaN
# 10                            Briggsdale                no      NaN       NaN
# 11                              Bushnell                no     00FA       NaN
# 12                             Riverview                no     00FD       NaN
# 13                            Okeechobee                no     00FL       NaN
# 14                              Lithonia                no     00GA       NaN
# 15                                 Hiram                no     00GE       NaN
# 16                           Kailua/Kona                no     00HI       NaN
# 17                            Clark Fork                no     00ID       NaN
# 18                              McDonald                no     00IG       NaN
# 19                            Chesterton                no     00II       NaN
# 20                                  Polo                no     00IL       NaN
# 21                                Hobart                no     00IN       NaN
# 22                                 Kings                no     00IS       NaN
# 23                               Gardner                no     00KS       NaN
# 24                              Stanford                no     00KY       NaN
# 25                              Gonzales                no     00LA       NaN
# 26                               Chatham                no     00LL       NaN
# 27                             Esterwood                no     00LS       NaN
# 28                          Federalsburg                no     00MD       NaN
# 29                             Ludington                no     00MI       NaN
# ...                                  ...               ...      ...       ...
# 14571                           Wildwood                no     CJJ3       NaN
# 14941                         Lethbridge                no     CLA5       NaN
# 14958                                NaN                no     CLJ3       NaN
# 14967                                NaN                no     CLN4       NaN
# 14972                                NaN                no     CLS3       NaN
# 14973                            Stayner                no     CLV2       NaN
# 14987  Agnico-Eagle Meadowbank Gold Mine                no     CMB2       NaN
# 15290                                NaN                no     CNL7       NaN
# 15525                                NaN                no     COR2       NaN
# 15722                                NaN                no     CRS7       NaN
# 15723                           Roberval                no     CRT2       NaN
# 15804                                NaN                no     CSM7       NaN
# 15850                                NaN                no     CSV8       NaN
# 16120                                NaN                no     CVB2       NaN
# 16142                                NaN                no     CWF2       NaN
# 16148                                NaN                no     CWP3       NaN
# 31432                           Budapest                no     LHKK       NaN
# 32086                           Ploiesti                no     LRPV       NaN
# 32761                            La Vega                no     MDER       NaN
# 32762                           Valverde                no     MDES       NaN
# 32764                           Barahona                no     MDHN       NaN
# 32766                                NaN                no     MDJI       NaN
# 32767                                NaN               yes     MDLL       NaN
# 32768                      San Cristobal                no     MDLM       NaN
# 32770                          La Romana                no     MDMA       NaN
# 32773                       Monte Cristi                no     MDPM       NaN
# 32784                       Monte Cristi                no     MDWO       NaN
# 39223                            Igaliku               yes     BGIO       QFX
# 39364               Makinohara / Shimada               yes     RJNS       FSZ
# 45469                                NaN                no     SPGL       NaN
#
#       local_code                                          home_link  \
# 0            00A                                                NaN
# 1           00AA                                                NaN
# 2           00AK                                                NaN
# 3           00AL                                                NaN
# 4            NaN                                                NaN
# 5           00AS                                                NaN
# 6           00AZ                                                NaN
# 7           00CA                                                NaN
# 8           00CL                                                NaN
# 9           00CN                                                NaN
# 10           NaN                                                NaN
# 11          00FA                                                NaN
# 12          00FD                                                NaN
# 13          00FL                                                NaN
# 14          00GA                                                NaN
# 15          00GE                                                NaN
# 16          00HI                                                NaN
# 17          00ID                                                NaN
# 18          00IG                                                NaN
# 19          00II                                                NaN
# 20          00IL                                                NaN
# 21          00IN                                                NaN
# 22          00IS                                                NaN
# 23          00KS                                                NaN
# 24          00KY                                                NaN
# 25          00LA                                                NaN
# 26          00LL                                                NaN
# 27          00LS                                                NaN
# 28          00MD                                                NaN
# 29          00MI                                                NaN
# ...          ...                                                ...
# 14571       CJJ3                                                NaN
# 14941        NaN                                                NaN
# 14958        NaN                                                NaN
# 14967       CLN4                                                NaN
# 14972        NaN                                                NaN
# 14973       CLV2                                                NaN
# 14987       CMB2                                                NaN
# 15290        NaN                                                NaN
# 15525        NaN                                                NaN
# 15722        NaN                                                NaN
# 15723       CRT2                        http://www.airroberval.com/
# 15804        NaN                                                NaN
# 15850        NaN                                                NaN
# 16120       CVB2                                                NaN
# 16142        NaN                                                NaN
# 16148        NaN                                                NaN
# 31432        NaN                http://www.kiskunlachaza-airport.hu
# 32086        NaN  http://aeroclubulromaniei.ro/schools/ploiesti-...
# 32761        NaN                                                NaN
# 32762        NaN                                                NaN
# 32764        NaN                                                NaN
# 32766        NaN                                                NaN
# 32767        NaN                                                NaN
# 32768        NaN                                                NaN
# 32770        NaN                                                NaN
# 32773        NaN                                                NaN
# 32784        NaN                                                NaN
# 39223        NaN                                                NaN
# 39364        NaN  http://www.mtfuji-shizuokaairport.jp/english/i...
# 45469        NaN                                                NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 14571  https://en.wikipedia.org/wiki/Wildwood/Loche_M...
# 14941                                                NaN
# 14958                                                NaN
# 14967                                                NaN
# 14972                                                NaN
# 14973  https://en.wikipedia.org/wiki/Stayner_(Clearvi...
# 14987  http://en.wikipedia.org/wiki/Meadowbank_Aerodrome
# 15290                                                NaN
# 15525                                                NaN
# 15722                                                NaN
# 15723                                                NaN
# 15804                                                NaN
# 15850                                                NaN
# 16120                                                NaN
# 16142                                                NaN
# 16148                                                NaN
# 31432  http://hu.wikipedia.org/wiki/Kiskunlacházi_rep...
# 32086                                                NaN
# 32761                                                NaN
# 32762                                                NaN
# 32764                                                NaN
# 32766                                                NaN
# 32767                                                NaN
# 32768                                                NaN
# 32770                                                NaN
# 32773                                                NaN
# 32784                                                NaN
# 39223                                                NaN
# 39364      http://en.wikipedia.org/wiki/Shizuoka_Airport
# 45469                                                NaN
#
#                                                 keywords
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   00AR
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                  00CO
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 14571                                                NaN
# 14941                                                NaN
# 14958                                                NaN
# 14967                                                NaN
# 14972                                                NaN
# 14973                                                NaN
# 14987                                                NaN
# 15290                                                NaN
# 15525                                                NaN
# 15722                                                NaN
# 15723                                                NaN
# 15804                                                NaN
# 15850                                                NaN
# 16120                                                NaN
# 16142                                                NaN
# 16148                                                NaN
# 31432  Lachaza, LHKK, Lacháza, Kiskunlacháza, Budapes...
# 32086                                                NaN
# 32761                                                NaN
# 32762                                                NaN
# 32764                                                NaN
# 32766                                                NaN
# 32767                                                NaN
# 32768                                                NaN
# 32770                                                NaN
# 32773                                                NaN
# 32784                                                NaN
# 39223                                            Igaliko
# 39364                                                NaN
# 45469                                                NaN
#
# [54800 rows x 18 columns]

# %%
type(airports.sort_values('ident'))
# Out:
# pandas.core.frame.DataFrame

# %%
airports.sort_values('ident')[:5]
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN     00AR

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airp
